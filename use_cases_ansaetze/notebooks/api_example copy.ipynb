# %%
import requests
from python_tools.helpers import get_yaml_var, get_secret
from infisical_sdk import InfisicalSDKClient
from dotenv import load_dotenv
import os
import json
load_dotenv()
# Out:
# True

# %%
base_url = get_yaml_var("app_fqdn", "../ansible/group_vars/group_vars.yml")

api_url = f"https://civicrm.correlaid.org/civicrm/ajax/api4/Contact/get"
api_key = os.getenv("CIVICRM_API_KEY")



headers = {
    "X-Civi-Auth": f"Bearer {api_key}",
    "X-Requested-With": "XMLHttpRequest"
}

data = {
    "params": '{"limit": 25}'
}

response = requests.post(api_url, headers=headers, data=data)
print(response.json())
# Out:
# {'values': [{'id': 1, 'contact_type': 'Organization', 'external_identifier': None, 'display_name': 'Default Organization', 'organization_name': 'Default Organization', 'contact_sub_type': None, 'do_not_email': False, 'do_not_phone': False, 'do_not_mail': False, 'do_not_sms': False, 'do_not_trade': False, 'is_opt_out': False, 'legal_identifier': None, 'sort_name': 'Default Organization', 'nick_name': None, 'legal_name': 'Default Organization', 'image_URL': None, 'preferred_communication_method': None, 'preferred_language': None, 'hash': None, 'source': None, 'communication_style_id': None, 'email_greeting_id': None, 'email_greeting_custom': None, 'email_greeting_display': None, 'postal_greeting_id': None, 'postal_greeting_custom': None, 'postal_greeting_display': None, 'addressee_id': None, 'addressee_custom': None, 'addressee_display': None, 'sic_code': None, 'user_unique_id': None, 'is_deleted': False, 'created_date': None, 'modified_date': '2025-08-04 22:36:26', 'preferred_mail_format': 'Both'}, {'id': 2, 'contact_type': 'Individual', 'external_identifier': None, 'display_name': 'Standalone Admin', 'contact_sub_type': None, 'first_name': 'Standalone', 'middle_name': None, 'last_name': 'Admin', 'do_not_email': False, 'do_not_phone': False, 'do_not_mail': False, 'do_not_sms': False, 'do_not_trade': False, 'is_opt_out': False, 'legal_identifier': None, 'sort_name': 'Admin, Standalone', 'nick_name': None, 'image_URL': None, 'preferred_communication_method': None, 'preferred_language': 'en_US', 'hash': 'ccf9e0a3f10fe458a46cf99e0b072352', 'source': None, 'prefix_id': None, 'suffix_id': None, 'formal_title': None, 'communication_style_id': 1, 'email_greeting_id': 1, 'email_greeting_custom': None, 'email_greeting_display': 'Dear Standalone', 'postal_greeting_id': 1, 'postal_greeting_custom': None, 'postal_greeting_display': 'Dear Standalone', 'addressee_id': 1, 'addressee_custom': None, 'addressee_display': 'Standalone Admin', 'job_title': None, 'gender_id': None, 'birth_date': None, 'is_deceased': False, 'deceased_date': None, 'user_unique_id': None, 'employer_id': None, 'is_deleted': False, 'created_date': '2025-08-04 22:36:37', 'modified_date': '2025-08-04 22:36:37', 'preferred_mail_format': 'Both'}, {'id': 3, 'contact_type': 'Individual', 'external_identifier': None, 'display_name': 'Lorem Junior VII', 'contact_sub_type': None, 'first_name': 'Lorem', 'middle_name': 'Ipsum', 'last_name': 'Junior', 'do_not_email': False, 'do_not_phone': False, 'do_not_mail': False, 'do_not_sms': False, 'do_not_trade': False, 'is_opt_out': False, 'legal_identifier': None, 'sort_name': 'Junior, Lorem VII', 'nick_name': None, 'image_URL': None, 'preferred_communication_method': None, 'preferred_language': 'en_US', 'hash': '13fd263c460a9cedcc83ca6860bd774c', 'source': None, 'prefix_id': None, 'suffix_id': 8, 'formal_title': None, 'communication_style_id': 1, 'email_greeting_id': 1, 'email_greeting_custom': None, 'email_greeting_display': 'Dear Lorem', 'postal_greeting_id': 1, 'postal_greeting_custom': None, 'postal_greeting_display': 'Dear Lorem', 'addressee_id': 1, 'addressee_custom': None, 'addressee_display': 'Lorem Ipsum Junior VII', 'job_title': None, 'gender_id': None, 'birth_date': None, 'is_deceased': False, 'deceased_date': None, 'user_unique_id': None, 'employer_id': None, 'is_deleted': False, 'created_date': '2025-08-05 14:53:50', 'modified_date': '2025-08-07 14:36:24', 'preferred_mail_format': 'Both'}, {'id': 4, 'contact_type': 'Individual', 'external_identifier': '1', 'display_name': 'Benno Rogge', 'contact_sub_type': None, 'first_name': 'Benno', 'middle_name': None, 'last_name': 'Rogge', 'do_not_email': False, 'do_not_phone': False, 'do_not_mail': False, 'do_not_sms': False, 'do_not_trade': False, 'is_opt_out': False, 'legal_identifier': None, 'sort_name': 'Rogge, Benno', 'nick_name': None, 'image_URL': None, 'preferred_communication_method': None, 'preferred_language': 'de_DE', 'hash': 'b4311a852fc222912f7214f54c15762e', 'source': None, ...
